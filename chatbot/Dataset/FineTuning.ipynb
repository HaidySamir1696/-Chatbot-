# %%
# !pip install cdqa
# Out:
# ...
#      |████████████████████████████████| 51kB 1.3MB/s
# ...
#      |████████████████████████████████| 102kB 3.4MB/s
# ...
#      |████████████████████████████████| 286kB 4.9MB/s
# ...
#      |████████████████████████████████| 10.5MB 5.0MB/s
# ...
#      |████████████████████████████████| 317kB 45.2MB/s
# ...
#      |████████████████████████████████| 6.7MB 22.2MB/s
# ...
#      |████████████████████████████████| 748.9MB 19kB/s
# ...
#      |████████████████████████████████| 92kB 4.3MB/s
# ...
#      |████████████████████████████████| 51kB 5.8MB/s
# ...
#      |████████████████████████████████| 890kB 37.9MB/s
# ...
#      |████████████████████████████████| 1.1MB 40.1MB/s
# ...
#   Created wheel for cdqa: filename=cdqa-1.3.9-cp36-none-any.whl size=47640 sha256=60b9e4553f8414784a493ddecfebf34ebcd08fce15cd9a5fa08abdfac5775587
#   Stored in directory: /root/.cache/pip/wheels/8b/9a/68/d3f7651ea29c30d1bebc9e946bf5a8cf922e1c86fb6b8a33d9
# ...

# %%
from cdqa.pipeline import QAPipeline
from cdqa.utils.download import download_model
# Out:
# /usr/local/lib/python3.6/dist-packages/tqdm/autonotebook/__init__.py:18: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
# Download model
download_model(model='bert-squad_1.1', dir='./models')

# %%
cdqa_pipeline = QAPipeline(reader='./models/bert_qa.joblib', max_df=1.0)
# Out:
# 100%|██████████| 231508/231508 [00:00<00:00, 2742770.84B/s]

# %%
path_to_json='/content/json files/cdqa-v1.1HyperBus_p19-26.json'
cdqa_pipeline.fit_reader(path_to_json)
# Out:
# Could not find answer: '' vs. 'Deep Power Down (DPD) operation mode Output Drive Strength Initial Latency Count (clock cycle count from the capture of CA1 to the beginning of data transfer) Fixed Initial Latency Option (device dependent effect) Hybrid Wrap Option (one wrapped access then switch to linear burst) Wrapped burst length and alignment (options supported are device dependent).'
# ...
# QAPipeline(reader=BertQA(adam_epsilon=1e-08, bert_model='bert-base-uncased',
#                          do_lower_case=True, fp16=False,
#                          gradient_accumulation_steps=1, learning_rate=5e-05,
#                          local_rank=-1, loss_scale=0, max_answer_length=30,
#                          n_best_size=20, no_cuda=False,
#                          null_score_diff_threshold=0.0, num_train_epochs=3.0,
#                          output_dir=None, predict_batch_size=8, seed=42,
#                          server_ip='', server_po..._size=8,
# ...

# %%
path_to_json='/content/json files/cdqa-v1.1HyperBus1.json'
cdqa_pipeline.fit_reader(path_to_json)
# Out:
# ...
# QAPipeline(reader=BertQA(adam_epsilon=1e-08, bert_model='bert-base-uncased',
#                          do_lower_case=True, fp16=False,
#                          gradient_accumulation_steps=1, learning_rate=5e-05,
#                          local_rank=-1, loss_scale=0, max_answer_length=30,
#                          n_best_size=20, no_cuda=False,
#                          null_score_diff_threshold=0.0, num_train_epochs=3.0,
#                          output_dir=None, predict_batch_size=8, seed=42,
#                          server_ip='', server_po..._size=8,
#                          verbose_logging=False, version_2_with_negative=False,
#                          warmup_proportion=0.1, warmup_steps=0),
#            retrieve_by_doc=False,
#            retriever=BM25Retriever(b=0.75, floor=None, k1=2.0, lowercase=True,
#                                    max_df=1.0, min_df=2, ngram_range=(1, 2),
#                                    preprocessor=None, stop_words='english',
# ...

# %%
path_to_json='/content/json files/cdqa-v1.1HyperBus2.json'
cdqa_pipeline.fit_reader(path_to_json)
# Out:
# ...
# QAPipeline(reader=BertQA(adam_epsilon=1e-08, bert_model='bert-base-uncased',
#                          do_lower_case=True, fp16=False,
#                          gradient_accumulation_steps=1, learning_rate=5e-05,
#                          local_rank=-1, loss_scale=0, max_answer_length=30,
#                          n_best_size=20, no_cuda=False,
#                          null_score_diff_threshold=0.0, num_train_epochs=3.0,
#                          output_dir=None, predict_batch_size=8, seed=42,
#                          server_ip='', server_po..._size=8,
#                          verbose_logging=False, version_2_with_negative=False,
#                          warmup_proportion=0.1, warmup_steps=0),
#            retrieve_by_doc=False,
#            retriever=BM25Retriever(b=0.75, floor=None, k1=2.0, lowercase=True,
#                                    max_df=1.0, min_df=2, ngram_range=(1, 2),
#                                    preprocessor=None, stop_words='english',
# ...

# %%
path_to_json='/content/json files/cdqa-v1.1HyperBus3.json'
cdqa_pipeline.fit_reader(path_to_json)
# Out:
# ...
# QAPipeline(reader=BertQA(adam_epsilon=1e-08, bert_model='bert-base-uncased',
#                          do_lower_case=True, fp16=False,
#                          gradient_accumulation_steps=1, learning_rate=5e-05,
#                          local_rank=-1, loss_scale=0, max_answer_length=30,
#                          n_best_size=20, no_cuda=False,
#                          null_score_diff_threshold=0.0, num_train_epochs=3.0,
#                          output_dir=None, predict_batch_size=8, seed=42,
#                          server_ip='', server_po..._size=8,
#                          verbose_logging=False, version_2_with_negative=False,
#                          warmup_proportion=0.1, warmup_steps=0),
#            retrieve_by_doc=False,
#            retriever=BM25Retriever(b=0.75, floor=None, k1=2.0, lowercase=True,
#                                    max_df=1.0, min_df=2, ngram_range=(1, 2),
#                                    preprocessor=None, stop_words='english',
# ...

# %%
path_to_json='/content/json files/cdqa-v1.1HyperBus4.json'
cdqa_pipeline.fit_reader(path_to_json)
# Out:
# ...
# QAPipeline(reader=BertQA(adam_epsilon=1e-08, bert_model='bert-base-uncased',
#                          do_lower_case=True, fp16=False,
#                          gradient_accumulation_steps=1, learning_rate=5e-05,
#                          local_rank=-1, loss_scale=0, max_answer_length=30,
#                          n_best_size=20, no_cuda=False,
#                          null_score_diff_threshold=0.0, num_train_epochs=3.0,
#                          output_dir=None, predict_batch_size=8, seed=42,
#                          server_ip='', server_po..._size=8,
#                          verbose_logging=False, version_2_with_negative=False,
#                          warmup_proportion=0.1, warmup_steps=0),
#            retrieve_by_doc=False,
#            retriever=BM25Retriever(b=0.75, floor=None, k1=2.0, lowercase=True,
#                                    max_df=1.0, min_df=2, ngram_range=(1, 2),
#                                    preprocessor=None, stop_words='english',
# ...

# %%
#saving fine tuned model
path_to_model='/content/models/bert_qa_finetuned.joblib'
cdqa_pipeline.dump_reader(path_to_model)
